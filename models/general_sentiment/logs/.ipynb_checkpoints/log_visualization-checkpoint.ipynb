# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from scipy.interpolate import griddata

mpl.font_manager.fontManager.addfont('/opt/localdata/Data/bea/nlp/bmi550/assignment2/Tinos-Regular.ttf')
mpl.rc('font', family='Tinos')

# %%
log_path = "./roberta_opt_2.json"

# open the log file
opt_df = pd.read_json(log_path, lines=True)
opt_df
# Out:
#      final                                             params  test_loss  \
# 0    False  {'dropout_proportion': 0.722161928459056, 'lea...   0.955882
# 1    False  {'dropout_proportion': 0.7594228261290941, 'le...   1.253219
# 2    False  {'dropout_proportion': 0.8780808911239141, 'le...   1.628864
# 3    False  {'dropout_proportion': 0.587233970209022, 'lea...   0.936879
# 4    False  {'dropout_proportion': 0.613290675807255, 'lea...   1.093203
# ..     ...                                                ...        ...
# 96   False  {'dropout_proportion': 0.39829554422114805, 'l...   0.807931
# 97   False  {'dropout_proportion': 0.39830169963649803, 'l...   0.796660
# 98   False  {'dropout_proportion': 0.39824775701194304, 'l...   1.398432
# 99   False  {'dropout_proportion': 0.305052047614552, 'lea...   0.820893
# 100   True  {'dropout_proportion': 0.398286699456096, 'lea...   1.232712
#
#      test_acc  test_auc   test_f1  test_prec  test_rec
# 0    0.619565  0.754818  0.619565   0.619565  0.619565
# 1    0.657609  0.782141  0.657609   0.657609  0.657609
# 2    0.663043  0.782965  0.663043   0.663043  0.663043
# 3    0.652174  0.805435  0.652174   0.652174  0.652174
# 4    0.630435  0.766776  0.630435   0.630435  0.630435
# ..        ...       ...       ...        ...       ...
# 96   0.652174  0.805210  0.652174   0.652174  0.652174
# 97   0.619565  0.794987  0.619565   0.619565  0.619565
# 98   0.630435  0.732035  0.630435   0.630435  0.630435
# 99   0.673913  0.792958  0.673913   0.673913  0.673913
# 100  0.652174  0.791097  0.652174   0.652174  0.652174
#
# [101 rows x 8 columns]

# %%
opt_df.sort_values("test_f1", ascending=False)
# Out:
#     final                                             params  test_loss  \
# 72  False  {'dropout_proportion': 0.398286699456096, 'lea...   0.828414
# 85  False  {'dropout_proportion': 0.669788893839761, 'lea...   0.856583
# 70  False  {'dropout_proportion': 0.466471855681978, 'lea...   0.737055
# 27  False  {'dropout_proportion': 0.296447284259724, 'lea...   0.757787
# 53  False  {'dropout_proportion': 0.6698054121847381, 'le...   1.264017
# ..    ...                                                ...        ...
# 77  False  {'dropout_proportion': 0.7594440455955891, 'le...   1.015293
# 47  False  {'dropout_proportion': 0.290127796412244, 'lea...   0.909566
# 41  False  {'dropout_proportion': 0.296430093876138, 'lea...   0.840660
# 17  False  {'dropout_proportion': 0.48390671319710604, 'l...   0.783551
# 54  False  {'dropout_proportion': 0.355529398939789, 'lea...   1.096044
#
#     test_acc  test_auc   test_f1  test_prec  test_rec
# 72  0.706522  0.821941  0.706522   0.706522  0.706522
# 85  0.701087  0.821171  0.701087   0.701087  0.701087
# 70  0.695652  0.817677  0.695652   0.695652  0.695652
# 27  0.690217  0.792974  0.690217   0.690217  0.690217
# 53  0.690217  0.753961  0.690217   0.690217  0.690217
# ..       ...       ...       ...        ...       ...
# 77  0.608696  0.788954  0.608696   0.608696  0.608696
# 47  0.603261  0.763582  0.603261   0.603261  0.603261
# 41  0.597826  0.767285  0.597826   0.597826  0.597826
# 17  0.592391  0.796123  0.592391   0.592391  0.592391
# 54  0.592391  0.663533  0.592391   0.592391  0.592391
#
# [101 rows x 8 columns]

# %%
# extract the best performing parameters based on the monitor metric
best_idx = opt_df["test_f1"].idxmax()
best_param_dict = opt_df.loc[best_idx, 'params']
best_param_dict
# Out:
# {'dropout_proportion': 0.398286699456096,
#  'learning_rate': 3.6585311355012366e-05}

# %%
opt_df.loc[opt_df.final == True, :]
# Out:
#      final                                             params  test_loss  \
# 100   True  {'dropout_proportion': 0.398286699456096, 'lea...   1.232712
#
#      test_acc  test_auc   test_f1  test_prec  test_rec
# 100  0.652174  0.791097  0.652174   0.652174  0.652174

# %%
def visualize_v2(x_var: str, y_var: str, z_var: str, df, n: complex = 100j, method: str = 'cubic', best_param_dict: dict or None = None):
    """
    method can be 'linear', 'cubic', or 'nearest'
    """
    var_list = []
    n_list = []
    for var_name in [x_var, y_var]:
        # if variable is 'penalty', convert it to categorical
        var_list.append([d[var_name] for d in df['params']])
        n_list.append(n)
    
    # unpack var_list and n_list
    x_list, y_list = var_list
    x_n, y_n = n_list
    
    # create a grid to interpolate over
    grid_x, grid_y = np.mgrid[min(x_list):max(x_list):x_n, min(y_list):max(y_list):y_n]

    z_list = list(df[z_var])
#     print(z_list)
#     z_list = np.clip(z_list, 0.0, 1.0)

    # interpolate with griddata
    grid_z = griddata((x_list, y_list), z_list, (grid_x, grid_y), method=method, fill_value=0.0)

    fig, ax = plt.subplots(1, 1, dpi=150)
    
    # plot the interpolated data as a density map
    density_map = ax.imshow(
        grid_z.T, 
        extent=(
            min(x_list), 
            max(x_list), 
            min(y_list), 
            max(y_list)
        ), 
        origin='lower', 
        aspect='auto', 
        cmap='viridis',
#         interpolation='gaussian'
    )
    # plt.scatter(x_list, y_list, s=[(z**2)*10 for z in z_list])
    
    if best_param_dict is not None:
        ax.scatter(
            best_param_dict[x_var], 
            best_param_dict[y_var], 
            c='red', 
            marker='x', 
            label="Best Parameters"
        )
        ax.legend()
        

    x_title = x_var.replace('_', ' ').title()
    y_title = y_var.replace('_', ' ').title()
    
    # plt.yscale('log')
    fig.colorbar(density_map, label='F1 Score', ax=ax)
    ax.set_xlabel(x_title)
    ax.set_ylabel(y_title)
    ax.set_title(f'Heatmap of {x_title} vs {y_title}')
    plt.show()

# %%
visualize_v2(
    'dropout_proportion', 
    'learning_rate', 
    'test_f1', 
    opt_df[opt_df.final == False], 
    n=60j,
    method='linear',
    best_param_dict=best_param_dict
)
