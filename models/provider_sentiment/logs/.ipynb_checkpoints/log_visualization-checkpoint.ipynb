# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from scipy.interpolate import griddata

mpl.font_manager.fontManager.addfont('/opt/localdata/Data/bea/nlp/bmi550/assignment2/Tinos-Regular.ttf')
mpl.rc('font', family='Tinos')

# %%
log_path = "./roberta_opt_2.json"

# open the log file
opt_df = pd.read_json(log_path, lines=True)
opt_df
# Out:
#      final                                             params  test_loss  \
# 0    False  {'dropout_proportion': 0.722161928459056, 'lea...   0.493764
# 1    False  {'dropout_proportion': 0.7594228261290941, 'le...   0.451438
# 2    False  {'dropout_proportion': 0.8780808911239141, 'le...   0.560523
# 3    False  {'dropout_proportion': 0.587233970209022, 'lea...   0.387563
# 4    False  {'dropout_proportion': 0.613290675807255, 'lea...   0.436091
# ..     ...                                                ...        ...
# 96   False  {'dropout_proportion': 0.21037380116593402, 'l...   0.443857
# 97   False  {'dropout_proportion': 0.29015058043983605, 'l...   0.484508
# 98   False  {'dropout_proportion': 0.722212787262513, 'lea...   0.812617
# 99   False  {'dropout_proportion': 0.587227135588661, 'lea...   0.825308
# 100   True  {'dropout_proportion': 0.625164267677566, 'lea...   0.788524
#
#      test_acc  test_auc   test_f1  test_prec  test_rec
# 0    0.855615  0.815876  0.855615   0.855615  0.855615
# 1    0.860963  0.921001  0.860963   0.860963  0.860963
# 2    0.839572  0.797778  0.839572   0.839572  0.839572
# 3    0.855615  0.910666  0.855615   0.855615  0.855615
# 4    0.818182  0.914237  0.818182   0.818182  0.818182
# ..        ...       ...       ...        ...       ...
# 96   0.844920  0.875099  0.844920   0.844920  0.844920
# 97   0.866310  0.897656  0.866310   0.866310  0.866310
# 98   0.823529  0.749416  0.823529   0.823529  0.823529
# 99   0.828877  0.763574  0.828877   0.828877  0.828877
# 100  0.866310  0.845130  0.866310   0.866310  0.866310
#
# [101 rows x 8 columns]

# %%
opt_df.sort_values("test_f1", ascending=False)
# Out:
#     final                                             params  test_loss  \
# 16  False  {'dropout_proportion': 0.625164267677566, 'lea...   0.732886
# 94  False  {'dropout_proportion': 0.7222007415286671, 'le...   0.452526
# 64  False  {'dropout_proportion': 0.321593081248766, 'lea...   0.426014
# 74  False  {'dropout_proportion': 0.648887910170587, 'lea...   0.430841
# 48  False  {'dropout_proportion': 0.321611107305867, 'lea...   0.755593
# ..    ...                                                ...        ...
# 37  False  {'dropout_proportion': 0.5872467844692151, 'le...   0.624964
# 54  False  {'dropout_proportion': 0.355529398939789, 'lea...   0.766805
# 75  False  {'dropout_proportion': 0.321607784511992, 'lea...   0.536015
# 70  False  {'dropout_proportion': 0.290146897933792, 'lea...   0.914313
# 91  False  {'dropout_proportion': 0.210376625035077, 'lea...   1.053228
#
#     test_acc  test_auc   test_f1  test_prec  test_rec
# 16  0.877005  0.734221  0.877005   0.877005  0.877005
# 94  0.877005  0.898419  0.877005   0.877005  0.877005
# 64  0.877005  0.680012  0.877005   0.877005  0.877005
# 74  0.877005  0.894346  0.877005   0.877005  0.877005
# 48  0.871658  0.832664  0.871658   0.871658  0.871658
# ..       ...       ...       ...        ...       ...
# 37  0.818182  0.804066  0.818182   0.818182  0.818182
# 54  0.812834  0.790630  0.812834   0.812834  0.812834
# 75  0.807487  0.897217  0.807487   0.807487  0.807487
# 70  0.807487  0.800042  0.807487   0.807487  0.807487
# 91  0.598930  0.459574  0.598930   0.598930  0.598930
#
# [101 rows x 8 columns]

# %%
# extract the best performing parameters based on the monitor metric
best_idx = opt_df["test_f1"].idxmax()
best_param_dict = opt_df.loc[best_idx, 'params']
best_param_dict
# Out:
# {'dropout_proportion': 0.625164267677566,
#  'learning_rate': 5.097529378834347e-05}

# %%
opt_df.loc[opt_df.final == True, :]
# Out:
#      final                                             params  test_loss  \
# 100   True  {'dropout_proportion': 0.625164267677566, 'lea...   0.788524
#
#      test_acc  test_auc  test_f1  test_prec  test_rec
# 100   0.86631   0.84513  0.86631    0.86631   0.86631

# %%
def visualize_v2(x_var: str, y_var: str, z_var: str, df, n: complex = 100j, method: str = 'cubic', best_param_dict: dict or None = None):
    """
    method can be 'linear', 'cubic', or 'nearest'
    """
    var_list = []
    n_list = []
    for var_name in [x_var, y_var]:
        # if variable is 'penalty', convert it to categorical
        var_list.append([d[var_name] for d in df['params']])
        n_list.append(n)
    
    # unpack var_list and n_list
    x_list, y_list = var_list
    x_n, y_n = n_list
    
    # create a grid to interpolate over
    grid_x, grid_y = np.mgrid[min(x_list):max(x_list):x_n, min(y_list):max(y_list):y_n]

    z_list = list(df[z_var])
#     print(z_list)
#     z_list = np.clip(z_list, 0.0, 1.0)

    # interpolate with griddata
    grid_z = griddata((x_list, y_list), z_list, (grid_x, grid_y), method=method, fill_value=0.0)

    fig, ax = plt.subplots(1, 1, dpi=150)
    
    # plot the interpolated data as a density map
    density_map = ax.imshow(
        grid_z.T, 
        extent=(
            min(x_list), 
            max(x_list), 
            min(y_list), 
            max(y_list)
        ), 
        origin='lower', 
        aspect='auto', 
        cmap='viridis',
#         interpolation='gaussian'
    )
    # plt.scatter(x_list, y_list, s=[(z**2)*10 for z in z_list])
    
    if best_param_dict is not None:
        ax.scatter(
            best_param_dict[x_var], 
            best_param_dict[y_var], 
            c='red', 
            marker='x', 
            label="Best Parameters"
        )
        ax.legend()
        

    x_title = x_var.replace('_', ' ').title()
    y_title = y_var.replace('_', ' ').title()
    
    # plt.yscale('log')
    fig.colorbar(density_map, label='F1 Score', ax=ax)
    ax.set_xlabel(x_title)
    ax.set_ylabel(y_title)
    ax.set_title(f'Heatmap of {x_title} vs {y_title}')
    plt.show()

# %%
visualize_v2(
    'dropout_proportion', 
    'learning_rate', 
    'test_f1', 
    opt_df[opt_df.final == False], 
    n=60j,
    method='linear',
    best_param_dict=best_param_dict
)
